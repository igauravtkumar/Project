# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url="https://www.shopsy.in/search?q=mobile%20under%2050000"
r = requests.get(url)
print(r)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.text,'html')
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
np = soup.find_all('div',class_="sc-c50e187b-0 bkNEtl")
print(np)
# Out:
# [<div class="sc-c50e187b-0 bkNEtl" style="max-height:32px;line-height:16px">OnePlus 13R 5G (Astral Trail, 512 GB)</div>, <div class="sc-c50e187b-0 bkNEtl" style="max-height:32px;line-height:16px">OnePlus 13R 5G (Nebula Noir, 512 GB)</div>, <div class="sc-c50e187b-0 bkNEtl" style="max-height:32px;line-height:16px">Google Pixel 9A (Iris, 256 GB)</div>, <div class="sc-c50e187b-0 bkNEtl" style="max-height:32px;line-height:16px">SAMSUNG Galaxy S24 FE 5G (Graphite, 256 GB)</div>, <div class="sc-c50e187b-0 bkNEtl" style="max-height:32px;line-height:16px">Google Pixel 9A (Porcelain, 256 GB)</div>, <div class="sc-c50e187b-0 bkNEtl" style="max-height:32px;line-height:16px">Motorola Edge 50 Ultra 5G (Nordic Wood, 512 GB)</div>, <div class="sc-c50e187b-0 bkNEtl" style="max-height:32px;line-height:16px">SAMSUNG Galaxy A55 5G (Awesome Navy, 256 GB)</div>, <div class="sc-c50e187b-0 bkNEtl" style="max-height:32px;line-height:16px">SAMSUNG Galaxy S24 FE 5G (Mint, 256 GB)</div>, <div class="sc-c50e187
# ...

# %%
name=[]
for i in np:
  names=i.text
  name.append(names)
print(name)
print(len(name))
# Out:
# ['OnePlus 13R 5G (Astral Trail, 512 GB)', 'OnePlus 13R 5G (Nebula Noir, 512 GB)', 'Google Pixel 9A (Iris, 256 GB)', 'SAMSUNG Galaxy S24 FE 5G (Graphite, 256 GB)', 'Google Pixel 9A (Porcelain, 256 GB)', 'Motorola Edge 50 Ultra 5G (Nordic Wood, 512 GB)', 'SAMSUNG Galaxy A55 5G (Awesome Navy, 256 GB)', 'SAMSUNG Galaxy S24 FE 5G (Mint, 256 GB)', 'SAMSUNG Galaxy A56 5G (Awesome Graphite, 256 GB)', 'SAMSUNG Galaxy A56 5G (Awesome Olive, 256 GB)', 'SAMSUNG Galaxy S24 FE 5G (Graphite, 256 GB)', 'SAMSUNG Galaxy S24 FE 5G (Blue, 256 GB)', 'SAMSUNG Galaxy S24 FE 5G (Mint, 256 GB)', 'SAMSUNG Galaxy S23 5G (Cream, 256 GB)', '13 pro (Ceramic Black, 256 GB)', 'OPPO Reno13 Pro 5G (Graphite Grey, 256 GB)', 'Google Pixel 8 (Hazel, 256 GB)', 'Infinix Zero Flip 5G (Blossom Glow, 512 GB)', 'Infinix Zero Flip 5G (Rock Black, 512 GB)', 'IQOO 12 (Legend, 256 GB)', 'SAMSUNG Galaxy A56 5G (Awesome Light Gray, 256 GB)', 'MOTOROLA Razar 50 Flip (Koala Grey, 256 GB)', 'Apple iPhone 8 Plus (Silver, 64 GB)', 'Appl
# ...

# %%
p = soup.find_all("div", class_ = "css-146c3p1 r-cqee49 r-1vgyyaa r-1rsjblm r-13hce6t")
price=[]
for i in p:
  prices = i.text
  price.append(prices)
print(price)
print(len(price))
# Out:
# ['₹44,564', '₹46,800', '₹47,999', '₹49,999', '₹47,999', '₹41,999', '₹44,999', '₹46,770', '₹45,680', '₹47,989', '₹49,999', '₹49,990', '₹49,999', '₹47,999', '₹49,999', '₹49,999', '₹45,599', '₹45,410', '₹49,999', '₹49,900', '₹49,900']
# 21

# %%
k = soup.find_all("div", class_="css-146c3p1 r-183gjk9 r-1vgyyaa r-1rsjblm r-11wrixw")
Offer=[]
for i in k:
  off = i.text
  Offer.append(off)
print(Offer)
print(len(Offer))
# Out:
# ['14% off', '6% off', '27% off', '23% off', '27% off', '14% off', '15% off', '29% off', '30% off', '27% off', '47% off', '44% off', '9% off', '42% off', '37% off', '37% off', '24% off', '14% off', '33% off', '38% off', '33% off']
# 21

# %%
l = soup.find_all('div', class_="css-146c3p1 r-dnmrzs r-1udh08x r-1udbk01 r-3s2u2q r-1iln25a r-1h7g6bg r-1et8rh5 r-1enofrn r-1f6r7vd r-l4nmg1 r-1kihuf0 r-9iso6")
review=[]
for i in l:
  reviews=i.text
  review.append(reviews)
print(review)
print(len(review))
# Out:
# ['(164)', '(164)', '(39)', '(1,523)', '(39)', '(2,557)', '(1,464)', '(1,523)', '(95)', '(61)', '(1,523)', '(1,523)', '(1,523)', '(76,176)', '(18)', '(751)', '(18,071)', '(199)', '(199)', '(19)', '(61)', '(3,429)', '(3,429)']
# 23

# %%
min_length = min(len(name), len(price), len(Offer),   len(review))

# Trim all lists to the minimum length
name = name[:min_length]
price = price[:min_length]
Offer = Offer[:min_length]
review = review[:min_length]

# %%
df = pd.DataFrame({
    'Product Name': name,
    'Price': price,
    'Review': review,
    'Offer':Offer
})
print(df)
# Out:
#                                          Product Name    Price    Review  \
# 0               OnePlus 13R 5G (Astral Trail, 512 GB)  ₹44,564     (164)
# 1                OnePlus 13R 5G (Nebula Noir, 512 GB)  ₹46,800     (164)
# 2                      Google Pixel 9A (Iris, 256 GB)  ₹47,999      (39)
# 3         SAMSUNG Galaxy S24 FE 5G (Graphite, 256 GB)  ₹49,999   (1,523)
# 4                 Google Pixel 9A (Porcelain, 256 GB)  ₹47,999      (39)
# 5     Motorola Edge 50 Ultra 5G (Nordic Wood, 512 GB)  ₹41,999   (2,557)
# 6        SAMSUNG Galaxy A55 5G (Awesome Navy, 256 GB)  ₹44,999   (1,464)
# 7             SAMSUNG Galaxy S24 FE 5G (Mint, 256 GB)  ₹46,770   (1,523)
# 8    SAMSUNG Galaxy A56 5G (Awesome Graphite, 256 GB)  ₹45,680      (95)
# 9       SAMSUNG Galaxy A56 5G (Awesome Olive, 256 GB)  ₹47,989      (61)
# 10        SAMSUNG Galaxy S24 FE 5G (Graphite, 256 GB)  ₹49,999   (1,523)
# 11            SAMSUNG Galaxy S24 FE 5G (Blue, 256 GB)  ₹49,990   (1,523)
# ...

# %%
df['storage(in GB)'] = df['Product Name'].str.extract(r'(\d+\s*GB)')

df['storage(in GB)'] = df['storage(in GB)'].str.replace(" ", "")
df['storage(in GB)'] = df['storage(in GB)'].str.replace("GB", "")

print(df[['Product Name', 'storage(in GB)']].head(3))
# Out:
#                             Product Name storage(in GB)
# 0  OnePlus 13R 5G (Astral Trail, 512 GB)            512
# 1   OnePlus 13R 5G (Nebula Noir, 512 GB)            512
# 2         Google Pixel 9A (Iris, 256 GB)            256

# %%
df["Price"] = df["Price"].str.replace("₹", "")
df["Price"] = df["Price"].str.replace(",", "")
df["Offer"] = df["Offer"].str.replace("% off", "")
df["Review"] = df["Review"].str.replace(",", "")
df['Review'] = df['Review'].astype(str).str.replace(r"[()]", "", regex=True)

# %%
df['Price']=df['Price'].astype(int)
df['Review']=df['Review'].astype(int)
df['Offer']=df['Offer'].astype(int)

# %%
df['Product_Name'] = df['Product Name'].str.split('(').str[0].str.strip()
df.drop('Product Name', axis=1, inplace=True)
cols = ['Product_Name'] + [col for col in df.columns if col != 'Product_Name']
df = df[cols]

# %%
df
# Out:
#                  Product_Name  Price  Review  Offer storage(in GB)
# 0              OnePlus 13R 5G  44564     164     14            512
# 1              OnePlus 13R 5G  46800     164      6            512
# 2             Google Pixel 9A  47999      39     27            256
# 3    SAMSUNG Galaxy S24 FE 5G  49999    1523     23            256
# 4             Google Pixel 9A  47999      39     27            256
# 5   Motorola Edge 50 Ultra 5G  41999    2557     14            512
# 6       SAMSUNG Galaxy A55 5G  44999    1464     15            256
# 7    SAMSUNG Galaxy S24 FE 5G  46770    1523     29            256
# 8       SAMSUNG Galaxy A56 5G  45680      95     30            256
# 9       SAMSUNG Galaxy A56 5G  47989      61     27            256
# 10   SAMSUNG Galaxy S24 FE 5G  49999    1523     47            256
# 11   SAMSUNG Galaxy S24 FE 5G  49990    1523     44            256
# 12   SAMSUNG Galaxy S24 FE 5G  49999    1523      9            256
# ...

# %%
df.to_csv('Mobile_data.csv')

# %%
df = pd.read_csv('/content/Mobile_data.csv')
df.head()
# Out:
#    Unnamed: 0              Product_Name  Price  Review  Offer  storage(in GB)
# 0           0            OnePlus 13R 5G  44564     164     14             512
# 1           1            OnePlus 13R 5G  46800     164      6             512
# 2           2           Google Pixel 9A  47999      39     27             256
# 3           3  SAMSUNG Galaxy S24 FE 5G  49999    1523     23             256
# 4           4           Google Pixel 9A  47999      39     27             256

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# Product_Name      0
# Price             0
# Review            0
# Offer             0
# storage(in GB)    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
df['Product_Name'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Name'>

# %%
sns.histplot(df['Price'], kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
avg_price = df.groupby('Product_Name')['Price'].mean().sort_values()
plt.figure(figsize=(10, 5))
sns.barplot(x=avg_price.values, y=avg_price.index, palette='Blues_r')
plt.title('Average Price per Product')
plt.xlabel('Average Price')
plt.ylabel('Product Name')
plt.show()
# Out:
# <ipython-input-110-d009258f72e1>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_price.values, y=avg_price.index, palette='Blues_r')

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(data=df, x='Review', y='Price', hue='Product_Name', s=100)
plt.title('Review vs Price')
plt.xlabel('Number of Reviews')
plt.ylabel('Price')
plt.grid(True)

plt.legend(loc='upper right', title='Product Name')
plt.show()

# %%
storage_counts = df['storage(in GB)'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(storage_counts, labels=storage_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Storage Capacity Distribution')
plt.show()

# %%
df=df.drop(columns = ['Unnamed: 0','Product_Name'])

# %%
df.head()
# Out:
#    Price  Review  Offer  storage(in GB)
# 0  44564     164     14             512
# 1  46800     164      6             512
# 2  47999      39     27             256
# 3  49999    1523     23             256
# 4  47999      39     27             256

# %%
df.head()
# Out:
#    Price  Review  Offer  storage(in GB)
# 0  44564     164     14             512
# 1  46800     164      6             512
# 2  47999      39     27             256
# 3  49999    1523     23             256
# 4  47999      39     27             256

# %%
df.dtypes
# Out:
# Price             int64
# Review            int64
# Offer             int64
# storage(in GB)    int64
# dtype: object

# %%
x=df.drop(columns=['storage(in GB)'])
y=df['storage(in GB)']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.4

# %%
param_grid = [
    {'penalty':['l1','l2','elasticnet','none'],
    'C' : np.logspace(-4,4,20),
    'solver': ['lbfgs','newton-cg','liblinear','sag','saga'],
    'max_iter'  : [100,1000,2500,5000]
}
]

# %%
from sklearn.model_selection import GridSearchCV
clf = GridSearchCV(lr,param_grid = param_grid, cv = 3,
                   verbose=True,n_jobs=-1)
clf
# Out:
# GridSearchCV(cv=3, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid=[{'C': array([1.00000000e-04, 2.63665090e-04, 6.95192796e-04, 1.83298071e-03,
#        4.83293024e-03, 1.27427499e-02, 3.35981829e-02, 8.85866790e-02,
#        2.33572147e-01, 6.15848211e-01, 1.62377674e+00, 4.28133240e+00,
#        1.12883789e+01, 2.97635144e+01, 7.84759970e+01, 2.06913808e+02,
#        5.45559478e+02, 1.43844989e+03, 3.79269019e+03, 1.00000000e+04]),
#                           'max_iter': [100, 1000, 2500, 5000],
#                           'penalty': ['l1', 'l2', 'elasticnet', 'none'],
#                           'solver': ['lbfgs', 'newton-cg', 'liblinear', 'sag',
#                                      'saga']}],
#              verbose=True)

# %%
best_clf = clf.fit(x_train,y_train)
best_clf.best_estimator_
# Out:
# Fitting 3 folds for each of 1600 candidates, totalling 4800 fits
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=3.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 3120 fits failed out of a total of 4800.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 240 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
print(f'Accuracy - : {best_clf.score(x_train,y_train):.3f}')
# Out:
# Accuracy - : 0.875
